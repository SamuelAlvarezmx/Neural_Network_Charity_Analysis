# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf


from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Import our input dataset
diabetes_df = pd.read_csv('/content/gdrive/MyDrive/Neural_Networks/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 3s 8ms/step - loss: 0.9488 - accuracy: 0.3993
# Epoch 2/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8731 - accuracy: 0.4462
# Epoch 3/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8078 - accuracy: 0.4809
# Epoch 4/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7547 - accuracy: 0.5191
# Epoch 5/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7102 - accuracy: 0.5521
# Epoch 6/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6727 - accuracy: 0.6007
# Epoch 7/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6418 - accuracy: 0.6233
# Epoch 8/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6162 - accuracy: 0.6424
# Epoch 9/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5942 - accuracy: 0.6649
# Epoch 10/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5751 - accuracy: 0.7014
# Epoch 11/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5591 - accuracy: 0.7240
# Epoch 12/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5451 - accuracy: 0.7344
# Epoch 13/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5325 - accuracy: 0.7396
# Epoch 14/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5214 - accuracy: 0.7344
# Epoch 15/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5120 - accuracy: 0.7535
# Epoch 16/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5035 - accuracy: 0.7587
# Epoch 17/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4960 - accuracy: 0.7674
# Epoch 18/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4897 - accuracy: 0.7691
# Epoch 19/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4838 - accuracy: 0.7726
# Epoch 20/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4787 - accuracy: 0.7743
# Epoch 21/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4743 - accuracy: 0.7760
# Epoch 22/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4703 - accuracy: 0.7847
# Epoch 23/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4669 - accuracy: 0.7917
# Epoch 24/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4639 - accuracy: 0.7899
# Epoch 25/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4607 - accuracy: 0.7865
# Epoch 26/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4583 - accuracy: 0.7847
# Epoch 27/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4559 - accuracy: 0.7830
# Epoch 28/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4539 - accuracy: 0.7847
# Epoch 29/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4520 - accuracy: 0.7865
# Epoch 30/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4502 - accuracy: 0.7847
# Epoch 31/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4488 - accuracy: 0.7812
# Epoch 32/50
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4473 - accuracy: 0.7812
# Epoch 33/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4457 - accuracy: 0.7830
# Epoch 34/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4451 - accuracy: 0.7830
# Epoch 35/50
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4438 - accuracy: 0.7830
# Epoch 36/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.4425 - accuracy: 0.7812
# Epoch 37/50
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4419 - accuracy: 0.7830
# Epoch 38/50
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4407 - accuracy: 0.7847
# Epoch 39/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4401 - accuracy: 0.7865
# Epoch 40/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4391 - accuracy: 0.7865
# Epoch 41/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4381 - accuracy: 0.7865
# Epoch 42/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4375 - accuracy: 0.7865
# Epoch 43/50
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4367 - accuracy: 0.7865
# Epoch 44/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4360 - accuracy: 0.7865
# Epoch 45/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4355 - accuracy: 0.7865
# Epoch 46/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4348 - accuracy: 0.7847
# Epoch 47/50
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4336 - accuracy: 0.7847
# Epoch 48/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.4330 - accuracy: 0.7847
# Epoch 49/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4324 - accuracy: 0.7847
# Epoch 50/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4316 - accuracy: 0.7847
# 6/6 - 0s - loss: 0.4966 - accuracy: 0.7344 - 436ms/epoch - 73ms/step
# Loss: 0.4965744912624359, Accuracy: 0.734375
